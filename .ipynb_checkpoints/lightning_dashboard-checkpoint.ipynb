# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # USING RAW GEOTIFFs

# %%
import rasterio
from rasterio.plot import show
from matplotlib import pyplot

# %%
def getURL(type_name, data):
    # type are limited: [ VHRMC, VHRDC, VHRSC, VHRFC, VHRAC ]
    # date are of different formatting for each types.
    # dates = ["201302",  "2013_01_15", "xxxx", "201301", "2013_01_01"]
    # typeDateSampleMapping = {
    #     "VHRMC" : "201302", #2013+feb #monthly
    #     "VHRDC" : "2013_01_15", #2013+jan+15 #daily
    #     "VHRSC" : "xxx", # custom set #seasonal data
    #     "VHRFC" : "201301", # 2013 + 01 #full data
    #     # "VHRAC" : "2013_01_01" # annual
    # }

    seasons = {
        "spring": "2013_03_01",
        "summer": "2013_07_01",
        "autumn": "2013_10_01",
        "winter": "2013_12_01"
    }

    types_COG_map = {
        "annual": { "name": "VHRAC", "dt": "daily", "formatting_base": "2013_01_", "formatting": "2013_01_01"}, #annual
        # "durinal": { "name": "VHRDC", "dt": "Time", "formatting_base": "2013_01_15", "formatting": "2013_01_15"}, #2013+jan+15 #daily # additional 15 days from jan1. A closed list
        "monthly": { "name": "VHRMC", "dt": "Month", "formatting_base": "2013", "formatting": "201302"}, #2013+feb #monthly
        "season": { "name": "VHRSC", "dt": "Season", "formatting_base": "", "formatting": "xxx" }, # custom set #seasonal data
        "full": { "name": "VHRFC", "dt": "full", "formatting_base": "201301", "formatting": "201301" } , # 2013 + 01 #full data 
    }

    type = types_COG_map[type_name]

    Instruments = {
        "LIS": "LIS", 
        "OTD": "OTD"}

    # if(type_ip == "annual"):
    #     data = input("Enter day number (Hint: 1 to 365)")
    # elif(type_ip == "daily"):
    #     data = input("Enter hour (Hint: 24 hour format i.e. 0 to 23)")
    # elif(type_ip == "monthly"):
    #     data = input("Enter month number (Hint: 01 to 12)")
    # elif(type_ip == "season"):
    #     data = input("Enter season number (Hint: spring, summer, autumn, winter)")
    # # elif(type_ip == "full"):
    # #     data = input("")
    # else:
    #     print("wrong type input.")

    if (type_name == "season"):
        data = seasons[data]
        
    date = type[formatting_base] + data # NOTE: for full, we do not need any data offsets.
    baseUrl = "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband"
    url =  f"{baseUrl}/{type['name']}/{date}/{Instruments['LIS']}/" + "{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]"
    return url
    # "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRSC/2013_07_01/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]

# %%
# base configs and dictonary defination
baseurl = "https://ghrc-cog.s3.us-west-2.amazonaws.com/TRMM-LIS"

types_CGTIF = {
     "annual": { "name": "VHRAC", "dt": "Time"},
     "daily": { "name": "VHRDC", "dt": "Time"},
     "monthly": { "name": "VHRMC", "dt": "Month"},
     "season": { "name": "VHRSC", "dt": "Season"}
     #add for full
}

# %%
type_ip = input("Enter one of the following type: \n1.annual \n2.daily \n3.monthly \n2.season \n ==>")
# Out:
# Enter one of the following type:
# 1.annual
# 2.daily
# 3.monthly
# 2.season
#  ==> season

# %%
# Take inputs and based off it, generate URL
# type_ip = "monthly" # change it; take input
type = types_CGTIF[type_ip]
#data = "input data according to type_ip name" #maybe put a validation

# %%
if(type_ip == "annual"):
    data = input("Enter day number (Hint: 1 to 365)")
elif(type_ip == "daily"):
    data = input("Enter hour (Hint: 24 hour format i.e. 0 to 23)")
elif(type_ip == "monthly"):
    data = input("Enter month number (Hint: 1 to 12)")
elif(type_ip == "season"):
    data = input("Enter season number (Hint: 1 to 4)")
else:
    print("wrong type input.")
# Out:
# Enter season number (Hint: 1 to 4) 2

# %%
# The URL to fetch geotif image according to the input types
URL = f'{baseurl}/{type["name"]}_LIS_FRD_cogs/{type["name"]}_LIS_FRD_{type["dt"]}_{data}.0_co.tif'
print(URL)
# Out:
# https://ghrc-cog.s3.us-west-2.amazonaws.com/TRMM-LIS/VHRSC_LIS_FRD_cogs/VHRSC_LIS_FRD_Season_2.0_co.tif

# %%
dataset = rasterio.open(URL)
pyplot.figure(figsize=(50, 25))
# pyplot.imshow(dataset.read(1), cmap='gray')
# pyplot.show(dataset)
show(dataset)
# show(dataset.read(), transform=dataset.transform)
# Out:
# Warning 1: HTTP response code on https://ghrc-cog.s3.us-west-2.amazonaws.com/TRMM-LIS/VHRSC_LIS_FRD_cogs/VHRSC_LIS_FRD_Season_2.0_co.tif.msk: 403
# Warning 1: HTTP response code on https://ghrc-cog.s3.us-west-2.amazonaws.com/TRMM-LIS/VHRSC_LIS_FRD_cogs/VHRSC_LIS_FRD_Season_2.0_co.tif.MSK: 403
# <AxesSubplot:>

# %% [markdown]
# # ROUGH

# %%
# fig, (axr, axg, axb) = pyplot.subplots(1,3, figsize=(21,7))
# show((dataset, 1), ax=axr, cmap='Reds', title='red channel')
# show((dataset, 2), ax=axg, cmap='Greens', title='green channel')
# show((dataset, 3), ax=axb, cmap='Blues', title='blue channel')
# pyplot.show()

# %%
print(dataset.count)
print(f'{dataset.width} x  {dataset.height}')
print(dataset.crs)
# Out:
# 1
# 3600 x  760
# EPSG:4326

# %% [markdown]
# # PLOTLY MAPBOX INTEGRATION / Fetch from Tile-server

# %%
import plotly.io as pio
pio.renderers.default = 'iframe'

# %%
fig = px.choropleth_mapbox(color_continuous_scale="Viridis",
                           range_color=(0, 12),
                           mapbox_style="carto-positron",
                           zoom=3, center = {"lat": 37.0902, "lon": -95.7129},
                           opacity=0.5,
                          )

fig.update_layout(
    mapbox_layers=[
        {
            "sourcetype": "raster",
            "source": [
                # "https://basemap.nationalmap.gov/arcgis/rest/services/USGSImageryOnly/MapServer/tile/{z}/{y}/{x}",
                # "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRSC/2013_07_01/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267"
                # "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRSC/2013_03_01/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]"
                # "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRMC/201301/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]"
                # "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRDC/2013_01_01/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0,0.002]"
                "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRAC/2013_12_31/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]"
                # "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRFC/201301/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.325,23.426]"
            ]
        }
      ])
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
# print(fig.layout.mapbox.layers)
fig.layout.mapbox.zoom = 1
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_24.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# data_types = {
#     "TRMMLIS-Full": "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRFC/201301/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.325,23.426]",
#     "TRMMLIS-Seasonal": "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRSC/2013_03_01/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]",
#     "TRMMLIS-Monthly" : "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRMC/201301/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]",
#     "TRMMLIS-Diurnal" : "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRDC/2013_01_01/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0,0.002]",
#     "TRMMLIS-Daily" : "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRAC/2013_01_01/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]"
# }

data_types = {
    "TRMMLIS-Full": "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRFC/201301/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.325,23.426]",
    "TRMMLIS-Seasonal": "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRSC/2013_03_01/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]",
    "TRMMLIS-Monthly" : "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRMC/201301/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]",
    "TRMMLIS-Diurnal" : "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRDC/2013_01_01/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0,0.002]",
    "TRMMLIS-Daily" : "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRAC/2013_01_01/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]"
}

# %% [raw]
# # Before displaying the overlayed world map,
# 1. first get inputs from the user, which set of visualization that they want to do,
#    Options are:
#
#       a. Full
#       b. Seasonal
#       c. Monthly
#       d. Durinal (Twice a month)
#       e. Daily (Annual data)
#
# 2. Then get to know the granularity of the visualization type selected.
#    Options are:
#
#       a. nothing, If Full
#       b. 4 seasons ["spring", "summer", "autumn", "winter"], If Seasonal
#       c. 01 - 12, If monthly
#       d. If Durinal (0-23 data inputs in s3). in COG-api, it goes like this: ["01/01", "01/15", "02/01", "02/15", "03/01", "03/15"] and so on.
#       e. 01/01 - 12/31, If Daily #might use no of day to date converter.

# %%
viz_type = input("Enter one of the following visualization type: \n1.full \n2.seasonal \n3.monthly \n4.diurnal \n5.daily\n ==>")
# Out:
# Enter one of the following visualization type:
# 1.full
# 2.seasonal
# 3.monthly
# 4.diurnal
# 5.daily
#  ==> diurnal

# %%
def visuzalize_COG(layer_url):
    fig = px.choropleth_mapbox(color_continuous_scale="Viridis",
                               range_color=(0, 12),
                               mapbox_style="carto-positron",
                               zoom=3, center = {"lat": 37.0902, "lon": -95.7129},
                               opacity=0.5,
                              )

    fig.update_layout(
        mapbox_layers=[
            {
                "sourcetype": "raster",
                "source": [layer_url]
            }
          ])
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    # print(fig.layout.mapbox.layers)
    fig.layout.mapbox.zoom = 1
    fig.show()

#apply switch cases:

    
def formulate_url(type_c, date_c):
    cog_base_url = "https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband"
    
    type_date_url_end_mapping = {
        "full": "LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.325,23.426]",
        "seasonal": "LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]",
        "monthly" : "LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]",
        "diurnal" : "LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0,0.002]",
        "daily" : "LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0.00010455249866936356,0.06766455620527267]"
    }

    type_codes = {
        "full": "VHRFC",
        "seasonal": "VHRSC",
        "monthly" : "VHRMC",
        "diurnal" : "VHRDC",
        "daily" : "VHRAC"
    }
    # TODO: try catch error handling.
    cog_url_build = f"{type_codes[type_c]}/{date_c}"

    return f"{cog_base_url}/{cog_url_build}/{type_date_url_end_mapping[type_c]}"

# what handlers do is:
    # It is a pure function that:
    # ask for the date
    # manage the date
    # Formulate the url
    # use url for visuzalization

def handle_full():
    viz_date = "201301"
    viz_type = "full"
    viz_url = formulate_url(viz_type, viz_date)
    print(viz_url)
    # visuzalize_COG(viz_url)

def handle_seasonal():
    u_input = input("Enter the Season (Hint: \n1. spring \n2. summer \n3. autumn \n4. winter )\n==>")
    season_date_map = { 
        "spring": "2013_03_01",
        "summer": "2013_07_01",
        "autumn": "2013_10_01",
        "winter": "2013_12_01"
    }
    viz_date = season_date_map[u_input]
    viz_type = "seasonal"
    viz_url = formulate_url(viz_type, viz_date)
    print(viz_url)
    # visuzalize_COG(viz_url)

def handle_monthly():
    u_input = input("Enter the Month (Hint: 01 - 12)")
    # todo: check input validation
    viz_date = f"2013{u_input}"
    viz_type = "monthly"
    viz_url = formulate_url(viz_type, viz_date)
    print(viz_url)
    # visuzalize_COG(viz_url)


def handle_diurnal():
    u_input = input("Enter the Durinals (Hint: 00 - 23)")
    # todo: check input validation
    # if even, 01st of month
    # if odd, 15th of month
    season_date_map = {
        "00": "2013_01_01" , "01": "2013_01_15" , "02": "2013_02_01" , "03": "2013_02_15" , "04": "2013_03_01" , "05": "2013_03_15" ,
        "06": "2013_04_01" , "07": "2013_04_15" , "08": "2013_05_01" , "09": "2013_05_15" , "10": "2013_06_01" , "11": "2013_06_15" ,
        "12": "2013_07_01" , "13": "2013_07_15" , "14": "2013_08_01" , "15": "2013_08_15" , "16": "2013_09_01" , "17": "2013_09_15" ,
        "18": "2013_10_01" , "19": "2013_10_15" , "20": "2013_11_01" , "21": "2013_11_15" , "22": "2013_12_01" , "23": "2013_12_15"
    }
    viz_date = season_date_map[u_input]
    viz_type = "diurnal"
    viz_url = formulate_url(viz_type, viz_date)
    print(viz_url)
    # visuzalize_COG(viz_url)

def handle_daily():
    pass

switches = {
    "full" : handle_full,
    "seasonal" : handle_seasonal,
    "monthly" : handle_monthly,
    "diurnal" : handle_diurnal,
    "daily" : handle_daily
}

url_new = switches[viz_type]()
print(url_new)
# Out:
# Enter the Durinals (Hint: 00 - 23) 11
# https://wug8w3fg42.execute-api.us-west-2.amazonaws.com/development/singleband/VHRDC/2013_06_15/LIS/{z}/{x}/{y}.png?colormap=terrain&stretch_range=[0,0.002]
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_69.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# None
